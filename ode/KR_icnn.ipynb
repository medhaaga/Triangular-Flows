# %%
import jax
import jax.numpy as jnp
import jax.random as random
import jax.scipy as scipy
from scipy.integrate import RK45
import numpy as np
import torch
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from jax import grad, jit, vmap, jvp, vjp, jacrev, jacfwd
import sys
import pickle
sys.path.append("..")
key = random.PRNGKey(0)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
class AdamOptim:
    def __init__(self, eta, beta1, beta2, epsilon, params):
        self.m = jax.tree_map(lambda m: 0.0, params)
        self.v = jax.tree_map(lambda m: 0.0, params)
        self.beta1 = beta1
        self.beta2 = beta2
        self.epsilon = epsilon
        self.eta = eta
    def update(self, params, grads, t):
        self.m = jax.tree_map(lambda m, grads: self.beta1*m + (1-self.beta1)*grads, self.m, grads)
        self.v = jax.tree_map(lambda v, grads: self.beta2*v + (1-self.beta2)*(grads**2), self.v, grads)
        m_hat = jax.tree_map(lambda m: m/(1 - self.beta1**t), self.m)
        v_hat = jax.tree_map(lambda v: v/(1 - self.beta2**t), self.v)
        params = jax.tree_map(lambda p, m, v: p -  self.eta* m/(jnp.sqrt(v) + self.epsilon), params, m_hat, v_hat)
        return(params)

## The functional intializes both FICNN and PICNN 

def init_icnn_params(x_layer_widths, y_layer_widths, picnn = True):
  params = []
  for n_in_x, n_out_x, n_in_y, n_out_y in zip(x_layer_widths[:-1], x_layer_widths[1:], y_layer_widths[:-1], y_layer_widths[1:]):
    if(picnn):
      params.append(
          dict(weights_x=0.01*random.normal(key, shape = (n_out_x, n_in_x)),
          biases_x=0.01*random.normal(key, shape=(n_out_x,1)),
          weights_z=0.01*random.uniform(key, shape = (n_out_y, n_in_y)),
          #biases_z=0.01*random.normal(key, shape = (n_in_y,1)),
          #weights_zu=jnp.zeros(shape = (n_in_y, n_in_x)),
          weights_y=0.01*random.normal(key, shape = (n_out_y, 1)),
          biases_y=0.01*random.normal(key, shape = (1,1)),
          weights_yu=0.01*random.normal(key, shape = (1, n_in_x)),
          weights_u=0.01*random.normal(key, shape = (n_out_y, n_in_x)),
          biases=0.01*random.normal(key, shape = (n_out_y,1))
          ))
    else:
      params.append(
          dict(weights_z=0.01*random.uniform(key, shape = (n_out_y, n_in_y)),
          weights_y=0.01*random.normal(key, shape = (n_out_y, 1)),
          biases=0.01*random.normal(key, shape = (n_out_y,1))
          ))
  return(params)


#### one forward pass through the PICNN and FICNN

def picnn_forward(params, x, y):
  p_x = x.size
  p_z = params[0]['weights_z'].shape[1]
  u = jnp.reshape(x, (p_x,1))
  z = jnp.zeros(shape=(p_z,1))
  y = jnp.reshape(y, (1,1))
  *hidden, last = params
  for layer in hidden:
    z = jax.nn.softplus(layer['weights_z'] @ z + layer['weights_y'] @ jnp.multiply(y, (layer['weights_yu'] @ u + layer['biases_y'])) + layer['weights_u'] @ u + layer['biases'])
    u = jax.nn.softplus((layer['weights_x']) @ u + (layer['biases_x']))

  z = (last['weights_z'] @ z + last['weights_y'] @ (y*(last['weights_yu'] @ u + last['biases_y'])) + last['weights_u'] @ u + last['biases'])
  u = (last['weights_x']) @ u + (last['biases_x'])
  z = jnp.reshape(z, ())
  return z


def ficnn_forward(params, y):
  p_z = params[0]['weights_z'].shape[1]
  z = jnp.zeros(shape=(p_z,1))
  y = jnp.reshape(y, (1,1))
  *hidden, last = params
  for layer in hidden:
    z = jax.nn.softplus((layer['weights_z'] @ z) + (layer['weights_y'] @ y) + layer['biases'])
    
  z = (last['weights_z'] @ z) + (last['weights_y'] @ y) + last['biases']
  z = jnp.reshape(z, ())
  return z

vec_picnn = jax.vmap(picnn_forward, in_axes=[None, None, 0], out_axes = 0)
vec_ficnn = jax.vmap(ficnn_forward, in_axes=[None, 0], out_axes = 0)

#### Ties d ICNN to construct the forward pass through the traingular flow once
def flow_forward(params, z):
  d = z.shape[0]
  f_x = jnp.array([grad(ficnn_forward, argnums=1)(params[0], z[0])])
  for i in jnp.arange(1,d):
    f_x = jnp.append(f_x, grad(picnn_forward, argnums=2)(params[i], z[:i], z[i]))
  f_x = params[-1]['scale']*z + params[-1]['bias'] + f_x
  return f_x

vec_flow = jax.vmap(flow_forward, in_axes=[None, 0], out_axes=0)
dflow = jax.jacrev(flow_forward, argnums = 1)

def jac_det(params, z):
    d = z.shape[0]
    foo = grad(ficnn_forward, argnums=1)
    j = abs(params[-1]['scale'][0] + grad(foo, argnums=1)(params[0], z[0]))
    for i in jnp.arange(1,d):
        foo = grad(picnn_forward, argnums=2)
        j *= abs(params[-1]['scale'][i] + grad(foo, argnums=2)(params[i], z[:i], z[i]))
    return(j)

vec_jac_det = jax.vmap(jac_det, in_axes=[None, 0], out_axes = 0)

def KL_loss(params, samps):
    n = samps.shape[0]
    d = samps.shape[1]
    samp_flow = vec_flow(params, samps)
    loss = jnp.log(scipy.stats.multivariate_normal.pdf(samp_flow, mean = jnp.zeros((d,)), cov = jnp.identity(d)))
    loss = jnp.sum(loss)
    foo = jnp.log(vec_jac_det(params, samps))
    loss += jnp.sum(foo)
    
    loss = -loss/n
    for i in range(d):
        for layers in params[i]:
            loss += 1000*jnp.sum(layers['weights_z'][layers['weights_z'] < 0]**2)
    return(loss )

LEARNING_RATE = 0.01
BETA1 = 0.9
BETA2 = 0.999
EPSILON = 1e-8

# %% [markdown]
# ### Example 1: Inference of ODE parameters
#
# The goal is to describe two populations using Lotka–Volterra population model. This model describes the populations of interacting species using nonlinear coupled ODEs where the rates of change of the two populations depend on four parameters $u = (\alpha, \beta, \gamma, \delta) \in \mathbb{R}^4$. The states $p(t) \in \mathbb{R}_+^2$ evolve according to the following ODEs
# \begin{align*}
#     \dfrac{d p_1(t)}{d t } &= \alpha p_1(t) - \beta p_1(t)p_2(t)\\
#     \dfrac{d p_2(t)}{d t } &= -\gamma p_2(t) + \delta p_1(t)p_2(t)\,.
# \end{align*}
# The starting point is $p(0) = (30,1)$. An independent log-normal prior distribution is used for the parameters given by
#
# $$\log u \sim \mathcal{N}(m_u, 0.5I_4) \qquad m_u = (-0.125, -0.125, -3, -3) \,.$$
#
# We simulate the ODEs for $T=4$ time units and collect noisy observations of the state evey $\Delta t = 2$ time units, i.e. the observations are collected at $t = 2,4$. The observations are corrupted with log-normal noise,
# $$\log y_k \sim \mathcal{N}(p(k\Delta t), 10^{-4}I_2) \quad \text{for } k=1,2.$$

# %%
alpha, beta, gamma, delta = 0.92, 0.05, 1.5, 0.02
def ODE_RHS(t,y):
    comps1 = alpha*y[0] - beta*y[0]*y[1]
    comps2 = -gamma*y[1] + delta*y[0]*y[1]
    return(jnp.array([comps1,comps2]))

# %%
n = 2000
k = 1
key, subkey = random.split(key)
d = 2 + 2*k
means = jnp.array([ -0.125, -3, -0.125, -3])
xs = random.multivariate_normal(key, mean = jnp.sqrt(jnp.exp(means)), cov = 0.01*jnp.identity(4), shape = (n,))
xs = jnp.abs(xs)
ys = jnp.zeros(shape = (n,2*k))

for i in range(n):
    if(i % 100 == 0): print(i)
    alpha = xs[i,0]
    gamma = xs[i,2]
    ode_sol = RK45(fun = ODE_RHS, t0=0, y0=jnp.array([30,1]), t_bound=2)
 
    while(ode_sol.status == 'running'):
        ode_sol.step()
    ys = ys.at[i,].set(ode_sol.y)
key, subkey = random.split(key)
ys = ys + jnp.abs(random.multivariate_normal(subkey, mean = jnp.zeros(shape = (2*k,)), cov = jnp.identity(2*k), shape = (n,)))
samps = jnp.concatenate([xs[:,0].reshape((n,1)),xs[:,2].reshape((n,1)), ys], axis=1)
samps = (samps - jnp.average(samps, axis = 0))/jnp.std(samps, axis = 0)

'''
plt.rcParams["figure.figsize"] = (5,5)
plt.scatter(samps[:,0], samps[:,1])
plt.xlabel("X")
plt.ylabel("Y")
'''
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# '\nplt.rcParams["figure.figsize"] = (5,5)\nplt.scatter(samps[:,0], samps[:,1])\nplt.xlabel("X")\nplt.ylabel("Y")\n'

# %%
plt.rcParams["figure.figsize"] = (5*(d-1),4)
for i in range(d-1):
    plt.subplot(1,d-1,i+1)
    plt.scatter(samps[:,i], samps[:,i+1])
    plt.xlabel("Component-"+str(i+1))
    plt.ylabel("Component-"+str(i+2))

# %%
random.normal(key,shape = (10,))*random.normal(subkey,shape = (10,))
# Out:
# DeviceArray([-0.49229452,  0.00618487, -0.30150488,  0.28153625,
#               3.9814148 ,  0.22542086, -0.22172838,  0.30305636,
#              -2.1365185 ,  1.3560206 ], dtype=float32)

# %%
params = [init_icnn_params(x_layer_widths = [1, 2, 2, 1], y_layer_widths=[1, 3, 3, 1], picnn=False)]

for i in jnp.arange(1,d):
    params.append(init_icnn_params(x_layer_widths = [i, (i+1), (i+1), 1], y_layer_widths=[1, 3, 3, 1], picnn=True))
key, subkey = random.split(key)
params.append(dict(scale= .01*random.multivariate_normal(key, mean=jnp.zeros(d), cov=jnp.identity(d)), bias = .01*random.multivariate_normal(subkey, mean=jnp.zeros(d), cov=jnp.identity(d))))
z0 = jnp.zeros(shape = (d,))
print(flow_forward(params, z0), KL_loss(params, samps))
# Out:
# [-0.00314792 -0.01583762  0.02099616  0.00153238] 23.199543

# %%
params
# Out:
# [[{'weights_z': DeviceArray([[0.00724198],
#                 [0.00877402],
#                 [0.00543993]], dtype=float32),
#    'weights_y': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32),
#    'biases': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32)},
#   {'weights_z': DeviceArray([[0.00200939, 0.0017013 , 0.00035435],
#                 [0.0029698 , 0.00891117, 0.00466293],
#                 [0.00085653, 0.00498266, 0.00689496]], dtype=float32),
#    'weights_y': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32),
#    'biases': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32)},
#   {'weights_z': DeviceArray([[0.00724198, 0.00877402, 0.00543993]], dtype=float32),
#    'weights_y': DeviceArray([[-0.01979785]], dtype=float32),
#    'biases': DeviceArray([[-0.01979785]], dtype=float32)}],
#  [{'weights_x': DeviceArray([[ 0.01223563],
#                 [-0.00620721]], dtype=float32),
#    'biases_x': DeviceArray([[ 0.01223563],
#                 [-0.00620721]], dtype=float32),
#    'weights_z': DeviceArray([[0.00724198],
#                 [0.00877402],
#                 [0.00543993]], dtype=float32),
#    'weights_y': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32),
#    'biases_y': DeviceArray([[-0.01979785]], dtype=float32),
#    'weights_yu': DeviceArray([[-0.01979785]], dtype=float32),
#    'weights_u': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32),
#    'biases': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32)},
#   {'weights_x': DeviceArray([[ 0.00595359,  0.02715111],
#                 [ 0.001105  , -0.00732837]], dtype=float32),
#    'biases_x': DeviceArray([[ 0.01223563],
#                 [-0.00620721]], dtype=float32),
#    'weights_z': DeviceArray([[0.00200939, 0.0017013 , 0.00035435],
#                 [0.0029698 , 0.00891117, 0.00466293],
#                 [0.00085653, 0.00498266, 0.00689496]], dtype=float32),
#    'weights_y': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32),
#    'biases_y': DeviceArray([[-0.01979785]], dtype=float32),
#    'weights_yu': DeviceArray([[ 0.01223563, -0.00620721]], dtype=float32),
#    'weights_u': DeviceArray([[-0.00319175, -0.00938368],
#                 [ 0.00145982,  0.00827557],
#                 [ 0.0177041 ,  0.01268293]], dtype=float32),
#    'biases': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32)},
#   {'weights_x': DeviceArray([[ 0.01223563, -0.00620721]], dtype=float32),
#    'biases_x': DeviceArray([[-0.01979785]], dtype=float32),
#    'weights_z': DeviceArray([[0.00724198, 0.00877402, 0.00543993]], dtype=float32),
#    'weights_y': DeviceArray([[-0.01979785]], dtype=float32),
#    'biases_y': DeviceArray([[-0.01979785]], dtype=float32),
#    'weights_yu': DeviceArray([[ 0.01223563, -0.00620721]], dtype=float32),
#    'weights_u': DeviceArray([[ 0.01223563, -0.00620721]], dtype=float32),
#    'biases': DeviceArray([[-0.01979785]], dtype=float32)}],
#  [{'weights_x': DeviceArray([[-0.00319175, -0.00938368],
#                 [ 0.00145982,  0.00827557],
#                 [ 0.0177041 ,  0.01268293]], dtype=float32),
#    'biases_x': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32),
#    'weights_z': DeviceArray([[0.00724198],
#                 [0.00877402],
#                 [0.00543993]], dtype=float32),
#    'weights_y': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32),
#    'biases_y': DeviceArray([[-0.01979785]], dtype=float32),
#    'weights_yu': DeviceArray([[ 0.01223563, -0.00620721]], dtype=float32),
#    'weights_u': DeviceArray([[-0.00319175, -0.00938368],
#                 [ 0.00145982,  0.00827557],
#                 [ 0.0177041 ,  0.01268293]], dtype=float32),
#    'biases': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32)},
#   {'weights_x': DeviceArray([[-8.3827032e-03, -9.5365001e-03, -1.8063093e-02],
#                 [-5.3310553e-03,  1.2324922e-02, -8.4591965e-04],
#                 [-1.3680166e-02, -4.3461787e-05,  4.9442281e-03]],            dtype=float32),
#    'biases_x': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32),
#    'weights_z': DeviceArray([[0.00200939, 0.0017013 , 0.00035435],
#                 [0.0029698 , 0.00891117, 0.00466293],
#                 [0.00085653, 0.00498266, 0.00689496]], dtype=float32),
#    'weights_y': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32),
#    'biases_y': DeviceArray([[-0.01979785]], dtype=float32),
#    'weights_yu': DeviceArray([[0.00595359, 0.01162096, 0.001105  ]], dtype=float32),
#    'weights_u': DeviceArray([[-8.3827032e-03, -9.5365001e-03, -1.8063093e-02],
#                 [-5.3310553e-03,  1.2324922e-02, -8.4591965e-04],
#                 [-1.3680166e-02, -4.3461787e-05,  4.9442281e-03]],            dtype=float32),
#    'biases': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32)},
#   {'weights_x': DeviceArray([[0.00595359, 0.01162096, 0.001105  ]], dtype=float32),
#    'biases_x': DeviceArray([[-0.01979785]], dtype=float32),
#    'weights_z': DeviceArray([[0.00724198, 0.00877402, 0.00543993]], dtype=float32),
#    'weights_y': DeviceArray([[-0.01979785]], dtype=float32),
#    'biases_y': DeviceArray([[-0.01979785]], dtype=float32),
#    'weights_yu': DeviceArray([[0.00595359, 0.01162096, 0.001105  ]], dtype=float32),
#    'weights_u': DeviceArray([[0.00595359, 0.01162096, 0.001105  ]], dtype=float32),
#    'biases': DeviceArray([[-0.01979785]], dtype=float32)}],
#  [{'weights_x': DeviceArray([[ 0.00288583,  0.00848266, -0.00213748],
#                 [ 0.01489358,  0.00805278,  0.00057065],
#                 [-0.01581474, -0.01824819, -0.00582885],
#                 [ 0.01952785, -0.00474888,  0.01165285]], dtype=float32),
#    'biases_x': DeviceArray([[ 0.00595359],
#                 [ 0.02715111],
#                 [ 0.001105  ],
#                 [-0.00732837]], dtype=float32),
#    'weights_z': DeviceArray([[0.00724198],
#                 [0.00877402],
#                 [0.00543993]], dtype=float32),
#    'weights_y': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32),
#    'biases_y': DeviceArray([[-0.01979785]], dtype=float32),
#    'weights_yu': DeviceArray([[0.00595359, 0.01162096, 0.001105  ]], dtype=float32),
#    'weights_u': DeviceArray([[-8.3827032e-03, -9.5365001e-03, -1.8063093e-02],
#                 [-5.3310553e-03,  1.2324922e-02, -8.4591965e-04],
#                 [-1.3680166e-02, -4.3461787e-05,  4.9442281e-03]],            dtype=float32),
#    'biases': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32)},
#   {'weights_x': DeviceArray([[ 0.01764113,  0.01681032, -0.0025932 , -0.00381324],
#                 [-0.00034444,  0.00607888,  0.00671502, -0.01625664],
#                 [-0.01017996,  0.00882495,  0.01185863, -0.0024748 ],
#                 [ 0.00888305,  0.00218624, -0.01059209,  0.00134369]],            dtype=float32),
#    'biases_x': DeviceArray([[ 0.00595359],
#                 [ 0.02715111],
#                 [ 0.001105  ],
#                 [-0.00732837]], dtype=float32),
#    'weights_z': DeviceArray([[0.00200939, 0.0017013 , 0.00035435],
#                 [0.0029698 , 0.00891117, 0.00466293],
#                 [0.00085653, 0.00498266, 0.00689496]], dtype=float32),
#    'weights_y': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32),
#    'biases_y': DeviceArray([[-0.01979785]], dtype=float32),
#    'weights_yu': DeviceArray([[ 0.00595359,  0.02715111,  0.001105  , -0.00732837]], dtype=float32),
#    'weights_u': DeviceArray([[ 0.00288583,  0.00848266, -0.00213748,  0.01489358],
#                 [ 0.00805278,  0.00057065, -0.01581474, -0.01824819],
#                 [-0.00582885,  0.01952785, -0.00474888,  0.01165285]],            dtype=float32),
#    'biases': DeviceArray([[0.00595359],
#                 [0.01162096],
#                 [0.001105  ]], dtype=float32)},
#   {'weights_x': DeviceArray([[ 0.00595359,  0.02715111,  0.001105  , -0.00732837]], dtype=float32),
#    'biases_x': DeviceArray([[-0.01979785]], dtype=float32),
#    'weights_z': DeviceArray([[0.00724198, 0.00877402, 0.00543993]], dtype=float32),
#    'weights_y': DeviceArray([[-0.01979785]], dtype=float32),
#    'biases_y': DeviceArray([[-0.01979785]], dtype=float32),
#    'weights_yu': DeviceArray([[ 0.00595359,  0.02715111,  0.001105  , -0.00732837]], dtype=float32),
#    'weights_u': DeviceArray([[ 0.00595359,  0.02715111,  0.001105  , -0.00732837]], dtype=float32),
#    'biases': DeviceArray([[-0.01979785]], dtype=float32)}],
#  {'scale': DeviceArray([0.00212132, 0.01169001, 0.00331698, 0.00460713], dtype=float32),
#   'bias': DeviceArray([-0.01101029, -0.00749435, -0.00952365,  0.0049398 ], dtype=float32)}]

# %%
adam = AdamOptim(eta=LEARNING_RATE, beta1=BETA1, beta2=BETA2, epsilon=EPSILON, params=params)
kl = jnp.array([KL_loss(params, samps)])
diff = 10
itr = 0
print("Iter: ", itr, "KL loss: ", kl[itr], "Non-monotonicity metric: ", 0)

while (diff > 1e-8):
    itr += 1
    grads = grad(KL_loss, argnums=0)(params, samps)
    params = adam.update(params, grads, t=itr)
    kl = jnp.hstack((kl, KL_loss(params, samps)))
    diff = jnp.abs((kl[-1] - kl[-2])/kl[-2])
    if(itr % 10 ==0):
        reg = 0
        for i in range(d):
            for layers in params[i]:
                reg += jnp.sum(layers['weights_z'][layers['weights_z'] < 0]**2)
        print("Iter: ", itr, "KL loss: ", kl[itr], "Non-monotonicity metric: ", reg)
# Out:
# Iter:  0 KL loss:  25.369812 Non-monotonicity metric:  0
# Iter:  10 KL loss:  14.227104 Non-monotonicity metric:  0.0
# Iter:  20 KL loss:  12.394367 Non-monotonicity metric:  3.393779e-06
# Iter:  30 KL loss:  10.790102 Non-monotonicity metric:  0.0
# Iter:  40 KL loss:  8.357692 Non-monotonicity metric:  0.0
# Iter:  50 KL loss:  5.8507037 Non-monotonicity metric:  0.0
# Iter:  60 KL loss:  4.361461 Non-monotonicity metric:  0.0
# Iter:  70 KL loss:  3.6150663 Non-monotonicity metric:  0.0
# Iter:  80 KL loss:  3.239081 Non-monotonicity metric:  0.0
# Iter:  90 KL loss:  3.0251937 Non-monotonicity metric:  0.0
# Iter:  100 KL loss:  2.8655028 Non-monotonicity metric:  0.0
# Iter:  110 KL loss:  2.6926908 Non-monotonicity metric:  0.0
# Iter:  120 KL loss:  2.5179396 Non-monotonicity metric:  0.0
# Iter:  130 KL loss:  2.372934 Non-monotonicity metric:  0.0
# Iter:  140 KL loss:  2.2960742 Non-monotonicity metric:  0.0
# Iter:  150 KL loss:  2.234463 Non-monotonicity metric:  0.0
# Iter:  160 KL loss:  2.1856296 Non-monotonicity metric:  0.0
# Iter:  170 KL loss:  2.1461914 Non-monotonicity metric:  0.0
# Iter:  180 KL loss:  2.1101902 Non-monotonicity metric:  0.0
# Iter:  190 KL loss:  2.0802734 Non-monotonicity metric:  0.0
# Iter:  200 KL loss:  2.0524805 Non-monotonicity metric:  0.0
# Iter:  210 KL loss:  2.0245552 Non-monotonicity metric:  0.0
# Iter:  220 KL loss:  1.9957525 Non-monotonicity metric:  0.0
# Iter:  230 KL loss:  1.9655796 Non-monotonicity metric:  0.0
# Iter:  240 KL loss:  1.9338106 Non-monotonicity metric:  0.0
# Iter:  250 KL loss:  1.9040562 Non-monotonicity metric:  0.0
# Iter:  260 KL loss:  1.8711084 Non-monotonicity metric:  0.0
# Iter:  270 KL loss:  1.8418714 Non-monotonicity metric:  0.0
# Iter:  280 KL loss:  1.8137685 Non-monotonicity metric:  0.0
# Iter:  290 KL loss:  1.7859287 Non-monotonicity metric:  0.0
# Iter:  300 KL loss:  1.7580844 Non-monotonicity metric:  0.0
# Iter:  310 KL loss:  1.7289985 Non-monotonicity metric:  0.0
# Iter:  320 KL loss:  1.6989627 Non-monotonicity metric:  0.0
# Iter:  330 KL loss:  1.6714858 Non-monotonicity metric:  0.0
# Iter:  340 KL loss:  1.6453142 Non-monotonicity metric:  0.0
# Iter:  350 KL loss:  1.6230893 Non-monotonicity metric:  0.0
# Iter:  360 KL loss:  1.6040974 Non-monotonicity metric:  0.0
# Iter:  370 KL loss:  1.5883305 Non-monotonicity metric:  0.0
# Iter:  380 KL loss:  1.5738784 Non-monotonicity metric:  0.0
# Iter:  390 KL loss:  1.5679345 Non-monotonicity metric:  0.0
# Iter:  400 KL loss:  1.5525289 Non-monotonicity metric:  0.0
# Iter:  410 KL loss:  1.5424173 Non-monotonicity metric:  0.0
# Iter:  420 KL loss:  1.5342463 Non-monotonicity metric:  0.0
# Iter:  430 KL loss:  1.5274227 Non-monotonicity metric:  0.0
# Iter:  440 KL loss:  1.5197268 Non-monotonicity metric:  0.0
# Iter:  450 KL loss:  1.5133907 Non-monotonicity metric:  0.0
# Iter:  460 KL loss:  1.5076289 Non-monotonicity metric:  0.0
# Iter:  470 KL loss:  1.5023443 Non-monotonicity metric:  0.0
# Iter:  480 KL loss:  1.5044218 Non-monotonicity metric:  0.0
# Iter:  490 KL loss:  1.4942734 Non-monotonicity metric:  0.0
# Iter:  500 KL loss:  1.4893042 Non-monotonicity metric:  0.0
# Iter:  510 KL loss:  1.4853735 Non-monotonicity metric:  0.0
# Iter:  520 KL loss:  1.4819112 Non-monotonicity metric:  0.0
# Iter:  530 KL loss:  1.4787374 Non-monotonicity metric:  0.0
# Iter:  540 KL loss:  1.4758228 Non-monotonicity metric:  0.0
# Iter:  550 KL loss:  1.4731275 Non-monotonicity metric:  0.0
# Iter:  560 KL loss:  1.4715039 Non-monotonicity metric:  0.0
# Iter:  570 KL loss:  1.4685473 Non-monotonicity metric:  0.0
# Iter:  580 KL loss:  1.4668076 Non-monotonicity metric:  0.0
# Iter:  590 KL loss:  1.4642241 Non-monotonicity metric:  0.0
# Iter:  600 KL loss:  1.4615923 Non-monotonicity metric:  0.0
# Iter:  610 KL loss:  1.4604101 Non-monotonicity metric:  0.0
# Iter:  620 KL loss:  1.4581285 Non-monotonicity metric:  0.0
# Iter:  630 KL loss:  1.4561689 Non-monotonicity metric:  0.0
# Iter:  640 KL loss:  1.4562569 Non-monotonicity metric:  0.0
# Iter:  650 KL loss:  1.4534878 Non-monotonicity metric:  0.0
# Iter:  660 KL loss:  1.4524326 Non-monotonicity metric:  0.0
# Iter:  670 KL loss:  1.4500933 Non-monotonicity metric:  0.0
# Iter:  680 KL loss:  1.4489439 Non-monotonicity metric:  0.0
# Iter:  690 KL loss:  1.44752 Non-monotonicity metric:  0.0
# Iter:  700 KL loss:  1.446145 Non-monotonicity metric:  0.0
# Iter:  710 KL loss:  1.4447705 Non-monotonicity metric:  0.0
# Iter:  720 KL loss:  1.4436226 Non-monotonicity metric:  0.0
# Iter:  730 KL loss:  1.4515162 Non-monotonicity metric:  0.0
# Iter:  740 KL loss:  1.441501 Non-monotonicity metric:  0.0
# Iter:  750 KL loss:  1.4406573 Non-monotonicity metric:  0.0
# Iter:  760 KL loss:  1.4400039 Non-monotonicity metric:  0.0
# Iter:  770 KL loss:  1.4384502 Non-monotonicity metric:  0.0
# Iter:  780 KL loss:  1.4372622 Non-monotonicity metric:  0.0
# Iter:  790 KL loss:  1.4362304 Non-monotonicity metric:  0.0
# Iter:  800 KL loss:  1.4352705 Non-monotonicity metric:  0.0
# Iter:  810 KL loss:  1.4343286 Non-monotonicity metric:  0.0
# Iter:  820 KL loss:  1.4334424 Non-monotonicity metric:  0.0
# Iter:  830 KL loss:  1.4377358 Non-monotonicity metric:  0.0
# Iter:  840 KL loss:  1.4325888 Non-monotonicity metric:  0.0
# Iter:  850 KL loss:  1.4358623 Non-monotonicity metric:  0.0
# Iter:  860 KL loss:  1.4344112 Non-monotonicity metric:  0.0
# Iter:  870 KL loss:  1.4306855 Non-monotonicity metric:  0.0
# Iter:  880 KL loss:  1.4287803 Non-monotonicity metric:  0.0
# Iter:  890 KL loss:  1.4277402 Non-monotonicity metric:  0.0
# Iter:  900 KL loss:  1.4270346 Non-monotonicity metric:  0.0
# Iter:  910 KL loss:  1.4263443 Non-monotonicity metric:  0.0
# Iter:  920 KL loss:  1.4255474 Non-monotonicity metric:  0.0
# Iter:  930 KL loss:  1.4249443 Non-monotonicity metric:  0.0
# Iter:  940 KL loss:  1.42952 Non-monotonicity metric:  0.0
# Iter:  950 KL loss:  1.4254336 Non-monotonicity metric:  0.0
# Iter:  960 KL loss:  1.4233892 Non-monotonicity metric:  0.0
# Iter:  970 KL loss:  1.4228389 Non-monotonicity metric:  0.0
# Iter:  980 KL loss:  1.4317979 Non-monotonicity metric:  0.0
# Iter:  990 KL loss:  1.4218252 Non-monotonicity metric:  0.0
# Iter:  1000 KL loss:  1.4215903 Non-monotonicity metric:  0.0
# Iter:  1010 KL loss:  1.42069 Non-monotonicity metric:  0.0
# Iter:  1020 KL loss:  1.4197618 Non-monotonicity metric:  0.0
# Iter:  1030 KL loss:  1.4190704 Non-monotonicity metric:  0.0
# Iter:  1040 KL loss:  1.4185253 Non-monotonicity metric:  0.0
# Iter:  1050 KL loss:  1.4179473 Non-monotonicity metric:  0.0
# Iter:  1060 KL loss:  1.4173917 Non-monotonicity metric:  0.0
# Iter:  1070 KL loss:  1.4169023 Non-monotonicity metric:  0.0
# Iter:  1080 KL loss:  1.4168955 Non-monotonicity metric:  0.0
# Iter:  1090 KL loss:  1.4243027 Non-monotonicity metric:  0.0
# Iter:  1100 KL loss:  1.4154493 Non-monotonicity metric:  0.0
# Iter:  1110 KL loss:  1.4157696 Non-monotonicity metric:  0.0
# Iter:  1120 KL loss:  1.4242246 Non-monotonicity metric:  0.0
# Iter:  1130 KL loss:  1.4154785 Non-monotonicity metric:  0.0
# Iter:  1140 KL loss:  1.4140615 Non-monotonicity metric:  0.0
# Iter:  1150 KL loss:  1.4132164 Non-monotonicity metric:  0.0
# Iter:  1160 KL loss:  1.4127378 Non-monotonicity metric:  0.0
# Iter:  1170 KL loss:  1.41231 Non-monotonicity metric:  0.0
# Iter:  1180 KL loss:  1.4118887 Non-monotonicity metric:  0.0
# Iter:  1190 KL loss:  1.4114566 Non-monotonicity metric:  0.0
# Iter:  1200 KL loss:  1.4110312 Non-monotonicity metric:  0.0
# Iter:  1210 KL loss:  1.410627 Non-monotonicity metric:  0.0
# Iter:  1220 KL loss:  1.4102163 Non-monotonicity metric:  0.0
# Iter:  1230 KL loss:  1.4098086 Non-monotonicity metric:  0.0
# Iter:  1240 KL loss:  1.4094028 Non-monotonicity metric:  0.0
# Iter:  1250 KL loss:  1.4089996 Non-monotonicity metric:  0.0
# Iter:  1260 KL loss:  1.4085982 Non-monotonicity metric:  0.0
# Iter:  1270 KL loss:  1.4096006 Non-monotonicity metric:  0.0
# Iter:  1280 KL loss:  1.4112017 Non-monotonicity metric:  0.0
# Iter:  1290 KL loss:  1.4083408 Non-monotonicity metric:  0.0
# Iter:  1300 KL loss:  1.420874 Non-monotonicity metric:  0.0
# Iter:  1310 KL loss:  1.4072953 Non-monotonicity metric:  4.7440185e-10
# Iter:  1320 KL loss:  1.4067627 Non-monotonicity metric:  0.0
# Iter:  1330 KL loss:  1.4064091 Non-monotonicity metric:  0.0
# Iter:  1340 KL loss:  1.4060371 Non-monotonicity metric:  0.0
# Iter:  1350 KL loss:  1.4056333 Non-monotonicity metric:  0.0
# Iter:  1360 KL loss:  1.4052656 Non-monotonicity metric:  0.0
# Iter:  1370 KL loss:  1.4049067 Non-monotonicity metric:  0.0
# Iter:  1380 KL loss:  1.404542 Non-monotonicity metric:  0.0
# Iter:  1390 KL loss:  1.4041762 Non-monotonicity metric:  0.0
# Iter:  1400 KL loss:  1.4038165 Non-monotonicity metric:  0.0
# Iter:  1410 KL loss:  1.4034615 Non-monotonicity metric:  0.0
# Iter:  1420 KL loss:  1.4040371 Non-monotonicity metric:  0.0
# Iter:  1430 KL loss:  1.4037066 Non-monotonicity metric:  0.0
# Iter:  1440 KL loss:  1.4026005 Non-monotonicity metric:  0.0
# Iter:  1450 KL loss:  1.4022943 Non-monotonicity metric:  9.133451e-09
# Iter:  1460 KL loss:  1.4018995 Non-monotonicity metric:  0.0
# Iter:  1470 KL loss:  1.4014888 Non-monotonicity metric:  0.0
# Iter:  1480 KL loss:  1.4012256 Non-monotonicity metric:  0.0
# Iter:  1490 KL loss:  1.401165 Non-monotonicity metric:  0.0
# Iter:  1500 KL loss:  1.4030948 Non-monotonicity metric:  0.0
# Iter:  1510 KL loss:  1.409084 Non-monotonicity metric:  0.0
# Iter:  1520 KL loss:  1.4037173 Non-monotonicity metric:  0.0
# Iter:  1530 KL loss:  1.399958 Non-monotonicity metric:  0.0
# Iter:  1540 KL loss:  1.3992685 Non-monotonicity metric:  0.0
# Iter:  1550 KL loss:  1.3990206 Non-monotonicity metric:  0.0
# Iter:  1560 KL loss:  1.3985869 Non-monotonicity metric:  0.0
# Iter:  1570 KL loss:  1.3981982 Non-monotonicity metric:  0.0
# Iter:  1580 KL loss:  1.3981866 Non-monotonicity metric:  0.0
# Iter:  1590 KL loss:  1.4005449 Non-monotonicity metric:  0.0
# Iter:  1600 KL loss:  1.3983833 Non-monotonicity metric:  0.0
# Iter:  1610 KL loss:  1.3968838 Non-monotonicity metric:  0.0
# Iter:  1620 KL loss:  1.3965552 Non-monotonicity metric:  0.0
# Iter:  1630 KL loss:  1.3962729 Non-monotonicity metric:  0.0
# Iter:  1640 KL loss:  1.3959224 Non-monotonicity metric:  0.0
# Iter:  1650 KL loss:  1.3955591 Non-monotonicity metric:  0.0
# Iter:  1660 KL loss:  1.3952036 Non-monotonicity metric:  0.0
# Iter:  1670 KL loss:  1.3948452 Non-monotonicity metric:  0.0
# Iter:  1680 KL loss:  1.3944737 Non-monotonicity metric:  0.0
# Iter:  1690 KL loss:  1.3941475 Non-monotonicity metric:  0.0
# Iter:  1700 KL loss:  1.39375 Non-monotonicity metric:  0.0
# Iter:  1710 KL loss:  1.3933359 Non-monotonicity metric:  0.0
# Iter:  1720 KL loss:  1.393414 Non-monotonicity metric:  0.0
# Iter:  1730 KL loss:  1.3930132 Non-monotonicity metric:  0.0
# Iter:  1740 KL loss:  1.3926499 Non-monotonicity metric:  0.0
# Iter:  1750 KL loss:  1.3926622 Non-monotonicity metric:  0.0
# Iter:  1760 KL loss:  1.4162211 Non-monotonicity metric:  0.0
# Iter:  1770 KL loss:  1.3974288 Non-monotonicity metric:  0.0
# Iter:  1780 KL loss:  1.3930445 Non-monotonicity metric:  0.0
# Iter:  1790 KL loss:  1.3907734 Non-monotonicity metric:  0.0
# Iter:  1800 KL loss:  1.390125 Non-monotonicity metric:  0.0
# Iter:  1810 KL loss:  1.389685 Non-monotonicity metric:  0.0
# Iter:  1820 KL loss:  1.3895278 Non-monotonicity metric:  0.0
# Iter:  1830 KL loss:  1.3956215 Non-monotonicity metric:  0.0
# Iter:  1840 KL loss:  1.3883628 Non-monotonicity metric:  0.0
# Iter:  1850 KL loss:  1.3882915 Non-monotonicity metric:  0.0
# Iter:  1860 KL loss:  1.3875455 Non-monotonicity metric:  0.0
# Iter:  1870 KL loss:  1.3868632 Non-monotonicity metric:  0.0
# Iter:  1880 KL loss:  1.3863506 Non-monotonicity metric:  0.0
# Iter:  1890 KL loss:  1.3858438 Non-monotonicity metric:  0.0
# Iter:  1900 KL loss:  1.38531 Non-monotonicity metric:  0.0
# Iter:  1910 KL loss:  1.3855908 Non-monotonicity metric:  0.0
# Iter:  1920 KL loss:  1.3843735 Non-monotonicity metric:  0.0
# Iter:  1930 KL loss:  1.3838398 Non-monotonicity metric:  0.0
# Iter:  1940 KL loss:  1.3855195 Non-monotonicity metric:  0.0
# Iter:  1950 KL loss:  1.3825703 Non-monotonicity metric:  0.0
# Iter:  1960 KL loss:  1.3870991 Non-monotonicity metric:  0.0
# Iter:  1970 KL loss:  1.383123 Non-monotonicity metric:  0.0
# Iter:  1980 KL loss:  1.3834609 Non-monotonicity metric:  0.0
# Iter:  1990 KL loss:  1.3826748 Non-monotonicity metric:  0.0
# Iter:  2000 KL loss:  1.381767 Non-monotonicity metric:  0.0
# Iter:  2010 KL loss:  1.3811953 Non-monotonicity metric:  0.0
# Iter:  2020 KL loss:  1.3812549 Non-monotonicity metric:  0.0
# Iter:  2030 KL loss:  1.3833793 Non-monotonicity metric:  0.0
# Iter:  2040 KL loss:  1.3800058 Non-monotonicity metric:  0.0
# Iter:  2050 KL loss:  1.3789799 Non-monotonicity metric:  0.0
# Iter:  2060 KL loss:  1.3784848 Non-monotonicity metric:  0.0
# Iter:  2070 KL loss:  1.3779418 Non-monotonicity metric:  0.0
# Iter:  2080 KL loss:  1.377768 Non-monotonicity metric:  0.0
# Iter:  2090 KL loss:  1.3884194 Non-monotonicity metric:  0.0
# Iter:  2100 KL loss:  1.3764219 Non-monotonicity metric:  0.0
# Iter:  2110 KL loss:  1.3770957 Non-monotonicity metric:  0.0
# Iter:  2120 KL loss:  1.3820351 Non-monotonicity metric:  0.0
# Iter:  2130 KL loss:  1.378437 Non-monotonicity metric:  0.0
# Iter:  2140 KL loss:  1.3747144 Non-monotonicity metric:  5.0861624e-11
# Iter:  2150 KL loss:  1.3738536 Non-monotonicity metric:  0.0
# Iter:  2160 KL loss:  1.3734117 Non-monotonicity metric:  0.0
# Iter:  2170 KL loss:  1.3724873 Non-monotonicity metric:  0.0
# Iter:  2180 KL loss:  1.3718467 Non-monotonicity metric:  0.0
# Iter:  2190 KL loss:  1.3713603 Non-monotonicity metric:  0.0
# Iter:  2200 KL loss:  1.3709241 Non-monotonicity metric:  4.2202455e-09
# Iter:  2210 KL loss:  1.3703271 Non-monotonicity metric:  0.0
# Iter:  2220 KL loss:  1.3747876 Non-monotonicity metric:  0.0
# Iter:  2230 KL loss:  1.3737115 Non-monotonicity metric:  0.0
# Iter:  2240 KL loss:  1.3694609 Non-monotonicity metric:  0.0
# Iter:  2250 KL loss:  1.3692056 Non-monotonicity metric:  0.0
# Iter:  2260 KL loss:  1.3685899 Non-monotonicity metric:  0.0
# Iter:  2270 KL loss:  1.3779346 Non-monotonicity metric:  0.0
# Iter:  2280 KL loss:  1.3678969 Non-monotonicity metric:  0.0
# Iter:  2290 KL loss:  1.3676294 Non-monotonicity metric:  0.0
# Iter:  2300 KL loss:  1.3674268 Non-monotonicity metric:  0.0
# Iter:  2310 KL loss:  1.3666114 Non-monotonicity metric:  0.0
# Iter:  2320 KL loss:  1.3661797 Non-monotonicity metric:  0.0
# Iter:  2330 KL loss:  1.3656737 Non-monotonicity metric:  1.1406438e-07
# Iter:  2340 KL loss:  1.3652236 Non-monotonicity metric:  0.0
# Iter:  2350 KL loss:  1.3647988 Non-monotonicity metric:  0.0
# Iter:  2360 KL loss:  1.3642676 Non-monotonicity metric:  0.0
# Iter:  2370 KL loss:  1.3637671 Non-monotonicity metric:  0.0
# Iter:  2380 KL loss:  1.363274 Non-monotonicity metric:  0.0
# Iter:  2390 KL loss:  1.3707753 Non-monotonicity metric:  0.0
# Iter:  2400 KL loss:  1.3710781 Non-monotonicity metric:  0.0
# Iter:  2410 KL loss:  1.3664258 Non-monotonicity metric:  0.0
# Iter:  2420 KL loss:  1.3689454 Non-monotonicity metric:  0.0
# Iter:  2430 KL loss:  1.3636743 Non-monotonicity metric:  0.0
# Iter:  2440 KL loss:  1.3621787 Non-monotonicity metric:  0.0
# Iter:  2450 KL loss:  1.3618096 Non-monotonicity metric:  0.0
# Iter:  2460 KL loss:  1.3613316 Non-monotonicity metric:  0.0
# Iter:  2470 KL loss:  1.3614185 Non-monotonicity metric:  0.0
# Iter:  2480 KL loss:  1.3612133 Non-monotonicity metric:  0.0
# Iter:  2490 KL loss:  1.3601953 Non-monotonicity metric:  0.0
# Iter:  2500 KL loss:  1.3596627 Non-monotonicity metric:  0.0
# Iter:  2510 KL loss:  1.3611124 Non-monotonicity metric:  0.0
# Iter:  2520 KL loss:  1.3656992 Non-monotonicity metric:  0.0
# Iter:  2530 KL loss:  1.3600498 Non-monotonicity metric:  0.0
# Iter:  2540 KL loss:  1.3597724 Non-monotonicity metric:  0.0
# Iter:  2550 KL loss:  1.3596205 Non-monotonicity metric:  1.5852366e-07
# Iter:  2560 KL loss:  1.3592916 Non-monotonicity metric:  0.0
# Iter:  2570 KL loss:  1.3587676 Non-monotonicity metric:  0.0
# Iter:  2580 KL loss:  1.3586875 Non-monotonicity metric:  0.0
# Iter:  2590 KL loss:  1.3677417 Non-monotonicity metric:  0.0
# Iter:  2600 KL loss:  1.3584096 Non-monotonicity metric:  0.0
# Iter:  2610 KL loss:  1.3573828 Non-monotonicity metric:  0.0
# Iter:  2620 KL loss:  1.358961 Non-monotonicity metric:  0.0
# Iter:  2630 KL loss:  1.358664 Non-monotonicity metric:  0.0
# Iter:  2640 KL loss:  1.358582 Non-monotonicity metric:  0.0
# Iter:  2650 KL loss:  1.3633399 Non-monotonicity metric:  0.0
# Iter:  2660 KL loss:  1.3571982 Non-monotonicity metric:  0.0
# Iter:  2670 KL loss:  1.3566713 Non-monotonicity metric:  0.0
# Iter:  2680 KL loss:  1.356104 Non-monotonicity metric:  0.0
# Iter:  2690 KL loss:  1.3554648 Non-monotonicity metric:  0.0
# Iter:  2700 KL loss:  1.3550816 Non-monotonicity metric:  0.0
# Iter:  2710 KL loss:  1.3547041 Non-monotonicity metric:  0.0
# Iter:  2720 KL loss:  1.3543257 Non-monotonicity metric:  0.0
# Iter:  2730 KL loss:  1.3540151 Non-monotonicity metric:  3.283722e-11
# Iter:  2740 KL loss:  1.3625162 Non-monotonicity metric:  0.0
# Iter:  2750 KL loss:  1.3627851 Non-monotonicity metric:  0.0
# Iter:  2760 KL loss:  1.3560821 Non-monotonicity metric:  0.0
# Iter:  2770 KL loss:  1.3542315 Non-monotonicity metric:  0.0
# Iter:  2780 KL loss:  1.3572788 Non-monotonicity metric:  0.0
# Iter:  2790 KL loss:  1.3549453 Non-monotonicity metric:  0.0
# Iter:  2800 KL loss:  1.3531816 Non-monotonicity metric:  0.0
# Iter:  2810 KL loss:  1.3525127 Non-monotonicity metric:  0.0
# Iter:  2820 KL loss:  1.3518106 Non-monotonicity metric:  0.0
# Iter:  2830 KL loss:  1.3520503 Non-monotonicity metric:  0.0
# Iter:  2840 KL loss:  1.3517011 Non-monotonicity metric:  0.0
# Iter:  2850 KL loss:  1.3514248 Non-monotonicity metric:  0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/medhaaga/flows/ode/KR_icnn.ipynb Cell 9' in <cell line: 7>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bzh-ws1.cs.washington.edu/home/medhaaga/flows/ode/KR_icnn.ipynb#ch0000008vscode-remote?line=6'>7</a> while (diff > 1e-8):
#       <a href='vscode-notebook-cell://ssh-remote%2Bzh-ws1.cs.washington.edu/home/medhaaga/flows/ode/KR_icnn.ipynb#ch0000008vscode-remote?line=7'>8</a>     itr += 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bzh-ws1.cs.washington.edu/home/medhaaga/flows/ode/KR_icnn.ipynb#ch0000008vscode-remote?line=8'>9</a>     grads = grad(KL_loss, argnums=0)(params, samps)
#      <a href='vscode-notebook-cell://ssh-remote%2Bzh-ws1.cs.washington.edu/home/medhaaga/flows/ode/KR_icnn.ipynb#ch0000008vscode-remote?line=9'>10</a>     params = adam.update(params, grads, t=itr)
#      <a href='vscode-notebook-cell://ssh-remote%2Bzh-ws1.cs.washington.edu/home/medhaaga/flows/ode/KR_icnn.ipynb#ch0000008vscode-remote?line=10'>11</a>     kl = jnp.hstack((kl, KL_loss(params, samps)))
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/_src/api.py:987, in grad.<locals>.grad_f(*args, **kwargs)
#     984 @wraps(fun, docstr=docstr, argnums=argnums)
#     985 @api_boundary
#     986 def grad_f(*args, **kwargs):
# --> 987   _, g = value_and_grad_f(*args, **kwargs)
#     988   return g
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/_src/api.py:1069, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#    1067 _check_scalar(ans)
#    1068 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# -> 1069 g = vjp_py(lax_internal._one(ans))
#    1070 g = g[0] if isinstance(argnums, int) else g
#    1071 if not has_aux:
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/_src/tree_util.py:294, in _HashableCallableShim.__call__(self, *args, **kw)
#     293 def __call__(self, *args, **kw):
# --> 294   return self.fun(*args, **kw)
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/_src/api.py:2484, in _vjp_pullback_wrapper(cotangent_dtypes, cotangent_shapes, io_tree, fun, py_args)
#    2479   if np.shape(arg) != ct_shape:
#    2480     raise ValueError(
#    2481         f"Shape of cotangent input to vjp pullback function {np.shape(arg)} "
#    2482         "must be the same as the shape of corresponding primal input "
#    2483         f"{ct_shape}.")
# -> 2484 ans = fun(*args)
#    2485 return tree_unflatten(out_tree, ans)
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/_src/tree_util.py:294, in _HashableCallableShim.__call__(self, *args, **kw)
#     293 def __call__(self, *args, **kw):
# --> 294   return self.fun(*args, **kw)
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/interpreters/ad.py:140, in vjp.<locals>.unbound_vjp(pvals, jaxpr, consts, *cts)
#     138 cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#     139 dummy_args = [UndefinedPrimal(v.aval) for v in jaxpr.invars]
# --> 140 arg_cts = backward_pass(jaxpr, reduce_axes, True, consts, dummy_args, cts)
#     141 return map(instantiate_zeros, arg_cts)
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/interpreters/ad.py:235, in backward_pass(jaxpr, reduce_axes, transform_stack, consts, primals_in, cotangents_in)
#     233   params = dict(eqn.params)
#     234   call_jaxpr = params.pop('call_jaxpr')
# --> 235   cts_out = get_primitive_transpose(eqn.primitive)(
#     236       params, call_jaxpr, invals, cts_in, cts_in_avals, reduce_axes)
#     237 elif eqn.primitive in reducing_transposes:
#     238   cts_out = reducing_transposes[eqn.primitive](
#     239       reduce_axes, cts_in, *invals, **eqn.params)
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/interpreters/ad.py:612, in call_transpose(primitive, params, call_jaxpr, args, ct, _, reduce_axes)
#     610   in_type = [(core.raise_to_shaped(core.get_aval(x)), True) for x in all_args]
#     611   fun = lu.annotate(fun, tuple(in_type))
# --> 612 out_flat = primitive.bind(fun, *all_args, **params)
#     613 return tree_unflatten(out_tree(), out_flat)
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/core.py:1836, in CallPrimitive.bind(self, fun, *args, **params)
#    1835 def bind(self, fun, *args, **params):
# -> 1836   return call_bind(self, fun, *args, **params)
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/core.py:1852, in call_bind(primitive, fun, *args, **params)
#    1850 tracers = map(top_trace.full_raise, args)
#    1851 fun_ = lu.annotate(fun_, fun.in_type)
# -> 1852 outs = top_trace.process_call(primitive, fun_, tracers, params)
#    1853 return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/core.py:683, in EvalTrace.process_call(self, primitive, f, tracers, params)
#     682 def process_call(self, primitive, f, tracers, params):
# --> 683   return primitive.impl(f, *tracers, **params)
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/_src/dispatch.py:199, in _xla_call_impl(***failed resolving arguments***)
#     196 compiled_fun = xla_callable(fun, device, backend, name, donated_invars,
#     197                             keep_unused, *arg_specs)
#     198 try:
# --> 199   return compiled_fun(*args)
#     200 except FloatingPointError:
#     201   assert config.jax_debug_nans or config.jax_debug_infs  # compiled_fun can only raise in this case
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/_src/dispatch.py:712, in _execute_compiled(name, compiled, input_handler, output_buffer_counts, result_handler, has_unordered_effects, ordered_effects, kept_var_idx, *args)
#     710 device, = compiled.local_devices()
#     711 args, env = input_handler(args) if input_handler else (args, None)
# --> 712 in_flat = flatten(device_put(x, device) for i, x in enumerate(args)
#     713                   if i in kept_var_idx)
#     714 if has_unordered_effects or ordered_effects:
#     715   in_flat, token_handler = _add_tokens(has_unordered_effects, ordered_effects,
#     716                                        device, in_flat)
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/_src/util.py:111, in concatenate(xs)
#     109 def concatenate(xs: Iterable[Sequence[T]]) -> List[T]:
#     110   """Concatenates/flattens a list of lists."""
# --> 111   return list(it.chain.from_iterable(xs))
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/_src/dispatch.py:712, in <genexpr>(.0)
#     710 device, = compiled.local_devices()
#     711 args, env = input_handler(args) if input_handler else (args, None)
# --> 712 in_flat = flatten(device_put(x, device) for i, x in enumerate(args)
#     713                   if i in kept_var_idx)
#     714 if has_unordered_effects or ordered_effects:
#     715   in_flat, token_handler = _add_tokens(has_unordered_effects, ordered_effects,
#     716                                        device, in_flat)
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/_src/dispatch.py:978, in device_put(x, device)
#     976 x = xla.canonicalize_dtype(x)
#     977 try:
# --> 978   return device_put_handlers[type(x)](x, device)
#     979 except KeyError as err:
#     980   raise TypeError(f"No device_put handler for type: {type(x)}") from err
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/_src/dispatch.py:1008, in _device_put_device_array(x, device)
#    1007 def _device_put_device_array(x: Union[device_array.DeviceArrayProtocol, device_array._DeviceArray], device: Optional[Device]):
# -> 1008   x = _copy_device_array_to_device(x, device)
#    1009   return (x.device_buffer,)
#
# File ~/miniconda3/envs/nf/lib/python3.10/site-packages/jax/_src/dispatch.py:1020, in _copy_device_array_to_device(x, device)
#    1017 if device is None:
#    1018   # no copying to be done because there's no target specified
#    1019   return x
# -> 1020 elif xb.get_device_backend(device).platform == x.device_buffer.platform():
#    1021   # source and target platforms are the same
#    1022   if x.device_buffer.device() == device:
#    1023     # no copying to be done because source equals target
#    1024     if x._device == device:
#
# KeyboardInterrupt:

# %%
plt.rcParams["figure.figsize"] = (5,5)
plt.xlabel("Number of iterations")
plt.ylabel("KL divergence")
plt.plot(jnp.arange(0, jnp.size(kl)), kl)
plt.savefig('optim_curve_dim4_softplus.png')

# %%
### Plotting the two ICNN f^j with respect to x_j for fixed other inputs

xs = jnp.reshape(jnp.linspace(-5, 5, 100), (100,1))
ys = vec_ficnn(params[0], xs)
plt.rcParams["figure.figsize"] = (3*d,5)
plt.subplot(1,d,1)
plt.plot(xs, ys)
plt.xlabel("y")
plt.ylabel(r"$f(y | \theta)$")
for i in jnp.arange(1,d):
    ys = vec_picnn(params[i], z0[:i], xs)
    plt.subplot(1,d,(i+1).item())
    plt.plot(xs, ys)
    plt.xlabel("y")
    plt.ylabel(r"$f(x,y | \theta)$")

plt.savefig('monotonicity_dim4_softplus.png')
plt.show()

# %%
z = vec_flow(params, samps)
print(jnp.std(z, axis = 0))
plt.rcParams["figure.figsize"] = (10,5*(d-1))
for i in range(2):
    plt.subplot((d-1),2,(2*i+1))
    plt.scatter(samps[:,2*i], samps[:,2*i+1])
    plt.xlabel("Component-"+str(2*i+1))
    plt.ylabel("Component-"+str(2*i+2))
    plt.title("Original data")
    plt.subplot((d-1),2,(2*i+2))
    plt.scatter(z[:,2*i],z[:,2*i+1])
    plt.xlabel("Component-"+str(2*i+1))
    plt.ylabel("Component-"+str(2*i+2))
    plt.title("Normalized data")
    plt.show
plt.savefig('scatterplot_dim4_softplus.png')
# Out:
# [0.9994475 0.9997484 0.9923751 0.9929077]

# %%
plt.rcParams["figure.figsize"] = (5,5)
for t in range(d):
    fig = sm.qqplot(z[:,t], line = '45')
    plt.savefig('qq_plots_dim4_softplus'+str(t+1)+'.png')
    plt.show()

# %%
with open('squareGaussian/params_dim4_softplus', 'wb') as file_handle:
    pickle.dump(params, file_handle)
